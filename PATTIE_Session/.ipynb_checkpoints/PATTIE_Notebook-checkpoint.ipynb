# %%
import json

with open("PATTIE_outline.json") as transcript_file:
    transcript = json.load(transcript_file)
    print(json.dumps(transcript, indent=4, sort_keys=False))
# Out:
# [
#     {
#         "Search Engine": "pattie.unc.edu"
#     },
#     {
#         "Query": "covid-19 UNC"
#     },
#     {
#         "Thought": "which question what are the expert faculty at unc chapel hill working on with respect to covid-19 research and development and who are those faculty experts"
#     },
#     {
#         "Voice Command": "Similar",
#         "Intention": "molecules"
#     },
#     {
#         "Thought": "note that there's a semantic distance quite large between clusters containing the concepts interventions strategies and then the other cluster containing the concepts represent molecules"
#     },
#     {
#         "Thought": "although represent in molecules seems to be very semantically similar to vaccine and sars-cov"
#     },
#     {
#         "Voice Command": "Similar",
#         "Intention": "interventions"
#     },
#     {
#         "Thought": "although the relationships are distance going to go ahead and collect them"
#     },
#     {
# ...
